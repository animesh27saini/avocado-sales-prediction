# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"E:\Projects\20th- REGRESSION PROJECT\RESUME PROJECT -- PRICE PREDICTION\avocado.csv")
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %% [markdown]
# #### Remove index from dataframe .reset_index(drop)

# %%
data = data.reset_index(drop = True)
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
data.to_csv("avocado.csv")

# %% [markdown]
# ### Starting you cleaning process

# %%
data = pd.read_csv(r"E:\Projects\20th- REGRESSION PROJECT\RESUME PROJECT -- PRICE PREDICTION\avocado.csv")
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
data.tail(10)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18239           2  2018-03-11          1.56      22128.42  2162.67  3194.25
# 18240           3  2018-03-04          1.54      17393.30  1832.24  1905.57
# 18241           4  2018-02-25          1.57      18421.24  1974.26  2482.65
# 18242           5  2018-02-18          1.56      17597.12  1892.05  1928.36
# 18243           6  2018-02-11          1.57      15986.17  1924.28  1368.32
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
data.shape
# Out:
# (18249, 14)

# %%
data.describe().T                ## .T is used for transposing the dataframe matrix
# Out:
#                 count           mean           std      min       25%  \
# Unnamed: 0    18249.0      24.232232  1.548104e+01     0.00     10.00
# AveragePrice  18249.0       1.405978  4.026766e-01     0.44      1.10
# Total Volume  18249.0  850644.013009  3.453545e+06    84.56  10838.58
# 4046          18249.0  293008.424531  1.264989e+06     0.00    854.07
# 4225          18249.0  295154.568356  1.204120e+06     0.00   3008.78
# 4770          18249.0   22839.735993  1.074641e+05     0.00      0.00
# Total Bags    18249.0  239639.202060  9.862424e+05     0.00   5088.64
# Small Bags    18249.0  182194.686696  7.461785e+05     0.00   2849.42
# Large Bags    18249.0   54338.088145  2.439660e+05     0.00    127.47
# XLarge Bags   18249.0    3106.426507  1.769289e+04     0.00      0.00
# year          18249.0    2016.147899  9.399385e-01  2015.00   2015.00
#
#                     50%        75%          max
# Unnamed: 0        24.00      38.00        52.00
# ...

# %%
data.values
# Out:
# array([[0, '2015-12-27', 1.33, ..., 'conventional', 2015, 'Albany'],
#        [1, '2015-12-20', 1.35, ..., 'conventional', 2015, 'Albany'],
#        [2, '2015-12-13', 0.93, ..., 'conventional', 2015, 'Albany'],
#        ...,
#        [9, '2018-01-21', 1.87, ..., 'organic', 2018, 'WestTexNewMexico'],
#        [10, '2018-01-14', 1.93, ..., 'organic', 2018, 'WestTexNewMexico'],
#        [11, '2018-01-07', 1.62, ..., 'organic', 2018, 'WestTexNewMexico']],
#       dtype=object)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# #### Appending and concatenating the series
#
#
# append(): Series & DataFrame method
# * Invocation:
# * s1.append(s2)
# * Stacks rows of s2 below s1
# <br>
# <br>
# <br>
# concat(): pandas module function<br>
# * Invocation:
# * pd.concat([s1, s2, s3])
# * Can stack row-wise or column-wise

# %% [markdown]
# ## Sorting

# %%
data.sort_values(["AveragePrice" , "year"] , ascending = [True , False])
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 15261          43  2017-03-05          0.44      64057.04      223.84
# 7412           47  2017-02-05          0.46    2200550.27  1200632.86
# 15473          43  2017-03-05          0.48      50890.73      717.57
# 15262          44  2017-02-26          0.49      44024.03      252.79
# 1716            0  2015-12-27          0.49    1137707.43   738314.80
# ...           ...         ...           ...           ...         ...
# 16720          18  2017-08-27          3.04      12656.32      419.06
# 16055          42  2017-03-12          3.05       2068.26     1043.83
# 14124           7  2016-11-06          3.12      19043.80     5898.49
# 17428          37  2017-04-16          3.17       3018.56     1255.55
# 14125           8  2016-10-30          3.25      16700.94     2325.93
#
#             4225      4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
data["AveragePrice"]
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %% [markdown]
# ### Subsetting multiple columns

# %%
data[["AveragePrice","year"]]
# Out:
#        AveragePrice  year
# 0              1.33  2015
# 1              1.35  2015
# 2              0.93  2015
# 3              1.08  2015
# 4              1.28  2015
# ...             ...   ...
# 18244          1.63  2018
# 18245          1.71  2018
# 18246          1.87  2018
# 18247          1.93  2018
# 18248          1.62  2018
#
# [18249 rows x 2 columns]

# %% [markdown]
# ### Subsetting rows

# %%
data["AveragePrice"] < 1
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 18244    False
# 18245    False
# 18246    False
# 18247    False
# 18248    False
# Name: AveragePrice, Length: 18249, dtype: bool

# %%
data[data["AveragePrice"] < 1]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume      4046  \
# 2               2  2015-12-13          0.93     118220.22    794.70
# 6               6  2015-11-15          0.99      83453.76   1368.92
# 7               7  2015-11-08          0.98     109428.33    703.75
# 13             13  2015-09-27          0.99     106803.39   1204.88
# 43             43  2015-03-01          0.99      55595.74    629.46
# ...           ...         ...           ...           ...       ...
# 17169          43  2017-03-05          0.99     155011.12  35367.23
# 17170          44  2017-02-26          0.99     171145.00  34520.03
# 17536          39  2017-04-02          0.98     402676.23  34093.33
# 17537          40  2017-03-26          0.90     456645.91  36169.35
# 17540          43  2017-03-05          0.99     367519.17  61166.48
#
#             4225    4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 2      109149.67  130.50     8145.35     8042.21      103.14          0.0
# ...

# %% [markdown]
# ### Subsetting based on text data

# %%
data[data["type"] == "organic"]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 9126            0  2015-12-27          1.83        989.55     8.16    88.59
# 9127            1  2015-12-20          1.89       1163.03    30.24   172.14
# 9128            2  2015-12-13          1.85        995.96    10.44   178.70
# 9129            3  2015-12-06          1.84       1158.42    90.29   104.18
# 9130            4  2015-11-29          1.94        831.69     0.00    94.73
# ...           ...         ...           ...           ...      ...      ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
# ...

# %% [markdown]
# ### Subsetting based on dates

# %%
data[data["Date"]<= "2015-02-04"]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046      4225  \
# 47             47  2015-02-01          0.99      70873.60  1353.90  60017.20
# 48             48  2015-01-25          1.06      45147.50   941.38  33196.16
# 49             49  2015-01-18          1.17      44511.28   914.14  31540.32
# 50             50  2015-01-11          1.24      41195.08  1002.85  31640.34
# 51             51  2015-01-04          1.22      40873.28  2819.50  28287.42
# ...           ...         ...           ...           ...      ...       ...
# 11928          46  2015-02-01          1.77       7210.19  1634.42   3012.44
# 11929          47  2015-01-25          1.63       7324.06  1934.46   3032.72
# 11930          48  2015-01-18          1.71       5508.20  1793.64   2078.72
# 11931          49  2015-01-11          1.69       6861.73  1822.28   2377.54
# 11932          50  2015-01-04          1.64       6182.81  1561.30   2958.17
#
# ...

# %% [markdown]
# ### Subsetting based on Multiple Conditions

# %%
data[(data["Date"] < "2015-02-04") & (data["type"]== "organic")]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 9173           47  2015-02-01          1.83       1228.51    33.12    99.36
# 9174           48  2015-01-25          1.89       1115.89    14.87   148.72
# 9175           49  2015-01-18          1.93       1118.47     8.02   178.78
# 9176           50  2015-01-11          1.77       1182.56    39.00   305.12
# 9177           51  2015-01-04          1.79       1373.95    57.42   153.88
# ...           ...         ...           ...           ...      ...      ...
# 11928          46  2015-02-01          1.77       7210.19  1634.42  3012.44
# 11929          47  2015-01-25          1.63       7324.06  1934.46  3032.72
# 11930          48  2015-01-18          1.71       5508.20  1793.64  2078.72
# 11931          49  2015-01-11          1.69       6861.73  1822.28  2377.54
# 11932          50  2015-01-04          1.64       6182.81  1561.30  2958.17
#
# ...

# %%
regionFilter = data["region"].isin(["Boston" , "SanDiego"])
data[regionFilter]                                                                    ## Shows All the entites which are from Sandiego and Boston
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 208             0  2015-12-27          1.13     450816.39  3886.27  346964.70
# 209             1  2015-12-20          1.07     489802.88  4912.37  390100.99
# 210             2  2015-12-13          1.01     549945.76  4641.02  455362.38
# 211             3  2015-12-06          1.02     488679.31  5126.32  407520.22
# 212             4  2015-11-29          1.19     350559.81  3609.25  272719.08
# ...           ...         ...           ...           ...      ...        ...
# 18100           7  2018-02-04          1.81      17454.74  1158.41    7388.27
# 18101           8  2018-01-28          1.91      17579.47  1145.64    8284.41
# 18102           9  2018-01-21          1.95      18676.37  1088.49    9282.37
# 18103          10  2018-01-14          1.81      21770.02  3285.98   14338.52
# 18104          11  2018-01-07          2.06      16746.82  5150.82    9366.31
#
# ...

# %%
regionFilter = data["region"].isin(["Boston" , "SanDiego"])
yearFilter = data["year"].isin(["2016","2017"])
data[regionFilter & yearFilter]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Date, AveragePrice, Total Volume, 4046, 4225, 4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %% [markdown]
# # Counting missing values

# %%
data.isna().any()
# Out:
# Unnamed: 0      False
# Date            False
# AveragePrice    False
# Total Volume    False
# 4046            False
# 4225            False
# 4770            False
# Total Bags      False
# Small Bags      False
# Large Bags      False
# XLarge Bags     False
# type            False
# year            False
# region          False
# dtype: bool

# %%
data.isna().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# ### filling missing values with mean conscideration

# %%
meanVal = data["AveragePrice"].mean()
data.fillna(meanVal)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
data["AveragePrice100"] = data["AveragePrice"]*100
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region  AveragePrice100
# 0  2015  Albany            133.0
# ...

# %% [markdown]
# ### Statistics

# %%
data["AveragePrice"].mean()
# Out:
# 1.405978409775878

# %%
data["Date"].max()
# Out:
# '2018-03-25'

# %%
data.describe().T
# Out:
#                    count           mean           std      min       25%  \
# Unnamed: 0       18249.0      24.232232  1.548104e+01     0.00     10.00
# AveragePrice     18249.0       1.405978  4.026766e-01     0.44      1.10
# Total Volume     18249.0  850644.013009  3.453545e+06    84.56  10838.58
# 4046             18249.0  293008.424531  1.264989e+06     0.00    854.07
# 4225             18249.0  295154.568356  1.204120e+06     0.00   3008.78
# 4770             18249.0   22839.735993  1.074641e+05     0.00      0.00
# Total Bags       18249.0  239639.202060  9.862424e+05     0.00   5088.64
# Small Bags       18249.0  182194.686696  7.461785e+05     0.00   2849.42
# Large Bags       18249.0   54338.088145  2.439660e+05     0.00    127.47
# XLarge Bags      18249.0    3106.426507  1.769289e+04     0.00      0.00
# year             18249.0    2016.147899  9.399385e-01  2015.00   2015.00
# AveragePrice100  18249.0     140.597841  4.026766e+01    44.00    110.00
#
# ...

# %%
def pct30(column):
    return column.quantile(0.3)

def pct50(column):
    return column.quantile(0.5)

data[["AveragePrice","Total Bags"]].agg([pct30,pct50])
# Out:
#        AveragePrice  Total Bags
# pct30          1.15    7316.634
# pct50          1.37   39743.830

# %% [markdown]
# ### Dropping Duplicates

# %%
temp = data.drop_duplicates(subset = ["year"])
temp
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 0              0  2015-12-27          1.33      64236.62   1036.74   54454.85
# 2808           0  2016-12-25          1.52      73341.73   3202.39   58280.33
# 5616           0  2017-12-31          1.47     113514.42   2622.70  101135.53
# 8478           0  2018-03-25          1.57     149396.50  16361.69  109045.03
#
#         4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0      48.16     8696.87     8603.62       93.25         0.00  conventional
# 2808  426.92    11432.09    11017.32      411.83         2.94  conventional
# 5616   20.25     9735.94     5556.98     4178.96         0.00  conventional
# 8478   65.45    23924.33    19273.80     4270.53       380.00  conventional
#
#       year  region  AveragePrice100
# 0     2015  Albany            133.0
# 2808  2016  Albany            152.0
# 5616  2017  Albany            147.0
# 8478  2018  Albany            157.0

# %% [markdown]
# ### Counting Categorical data

# %%
data["year"].value_counts(sort = True , ascending= False)
# Out:
# year
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: count, dtype: int64

# %%
data.groupby(["year" , "type"])["AveragePrice"].agg([min,max,np.median , np.mean])
# Out:
#                     min   max  median      mean
# year type
# 2015 conventional  0.49  1.59    1.08  1.077963
#      organic       0.81  2.79    1.67  1.673324
# 2016 conventional  0.51  2.20    1.08  1.105595
#      organic       0.58  3.25    1.53  1.571684
# 2017 conventional  0.46  2.22    1.30  1.294888
#      organic       0.44  3.17    1.72  1.735521
# 2018 conventional  0.56  1.74    1.14  1.127886
#      organic       1.01  2.30    1.55  1.567176

# %% [markdown]
# ### Pivot Tabels

# %%
data.pivot_table(index = ["year","type"],aggfunc = [min,max, np.median , np.mean], values = "AveragePrice")
# Out:
#                            min          max       median         mean
#                   AveragePrice AveragePrice AveragePrice AveragePrice
# year type
# 2015 conventional         0.49         1.59         1.08     1.077963
#      organic              0.81         2.79         1.67     1.673324
# 2016 conventional         0.51         2.20         1.08     1.105595
#      organic              0.58         3.25         1.53     1.571684
# 2017 conventional         0.46         2.22         1.30     1.294888
#      organic              0.44         3.17         1.72     1.735521
# 2018 conventional         0.56         1.74         1.14     1.127886
#      organic              1.01         2.30         1.55     1.567176

# %% [markdown]
# ### Visualizatriuon

# %%
data["AveragePrice"].hist(bins = 20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
regionFilter = data.groupby(["region"])["AveragePrice"].mean().head(10)
regionFilter
# Out:
# region
# Albany                 1.561036
# Atlanta                1.337959
# BaltimoreWashington    1.534231
# Boise                  1.348136
# Boston                 1.530888
# BuffaloRochester       1.516834
# California             1.395325
# Charlotte              1.606036
# Chicago                1.556775
# CincinnatiDayton       1.209201
# Name: AveragePrice, dtype: float64

# %%
regionFilter.plot(kind = "bar" , rot = 45 , title = "Average Price in 10 region")
# Out:
# <Axes: title={'center': 'Average Price in 10 region'}, xlabel='region'>

# %%
data.plot(x= "AveragePrice" , y = "Total Volume" , kind= "scatter")
# Out:
# <Axes: xlabel='AveragePrice', ylabel='Total Volume'>

# %% [markdown]
# ### Machine Learning Regression

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       18249 non-null  int64
#  1   Date             18249 non-null  object
#  2   AveragePrice     18249 non-null  float64
#  3   Total Volume     18249 non-null  float64
#  4   4046             18249 non-null  float64
#  5   4225             18249 non-null  float64
#  6   4770             18249 non-null  float64
#  7   Total Bags       18249 non-null  float64
#  8   Small Bags       18249 non-null  float64
#  9   Large Bags       18249 non-null  float64
#  10  XLarge Bags      18249 non-null  float64
#  11  type             18249 non-null  object
#  12  year             18249 non-null  int64
#  13  region           18249 non-null  object
#  14  AveragePrice100  18249 non-null  float64
# dtypes: float64(10), int64(2), object(3)
# memory usage: 2.1+ MB

# %%
data
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
data.isnull().sum().any()                                                    ##This have to be false
# Out:
# False

# %%
data.Date = data.Date.apply(pd.to_datetime)
data['Month']=data['Date'].apply(lambda x:x.month)
data.Month = data.Month.map({1:'JAN',2:'FEB',3:'MARCH',4:'APRIL',5:'MAY',6:'JUNE',7:'JULY',8:'AUG',9:'SEPT',10:'OCT',11:'NOV',12:'DEC'})
data
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0               0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 18244           7 2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8 2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9 2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
data.drop(['Date'],axis=1)
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0               0          1.33      64236.62  1036.74   54454.85   48.16
# 1               1          1.35      54876.98   674.28   44638.81   58.33
# 2               2          0.93     118220.22   794.70  109149.67  130.50
# 3               3          1.08      78992.15  1132.00   71976.41   72.58
# 4               4          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244           7          1.63      17074.83  2046.96    1529.20    0.00
# 18245           8          1.71      13888.04  1191.70    3431.50    0.00
# 18246           9          1.87      13766.76  1191.92    2452.79  727.94
# 18247          10          1.93      16205.22  1527.63    2981.04  727.01
# 18248          11          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
data = data.drop(["Unnamed: 0","4046","4225","4770"],axis =1)

# %%
data
# Out:
#             Date  AveragePrice  Total Volume  Total Bags  Small Bags  \
# 0     2015-12-27          1.33      64236.62     8696.87     8603.62
# 1     2015-12-20          1.35      54876.98     9505.56     9408.07
# 2     2015-12-13          0.93     118220.22     8145.35     8042.21
# 3     2015-12-06          1.08      78992.15     5811.16     5677.40
# 4     2015-11-29          1.28      51039.60     6183.95     5986.26
# ...          ...           ...           ...         ...         ...
# 18244 2018-02-04          1.63      17074.83    13498.67    13066.82
# 18245 2018-01-28          1.71      13888.04     9264.84     8940.04
# 18246 2018-01-21          1.87      13766.76     9394.11     9351.80
# 18247 2018-01-14          1.93      16205.22    10969.54    10919.54
# 18248 2018-01-07          1.62      17489.58    12014.15    11988.14
#
#        Large Bags  XLarge Bags          type  year            region  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             18249 non-null  datetime64[ns]
#  1   AveragePrice     18249 non-null  float64
#  2   Total Volume     18249 non-null  float64
#  3   Total Bags       18249 non-null  float64
#  4   Small Bags       18249 non-null  float64
#  5   Large Bags       18249 non-null  float64
#  6   XLarge Bags      18249 non-null  float64
#  7   type             18249 non-null  object
#  8   year             18249 non-null  int64
#  9   region           18249 non-null  object
#  10  AveragePrice100  18249 non-null  float64
#  11  Month            18249 non-null  object
# dtypes: datetime64[ns](1), float64(7), int64(1), object(3)
# memory usage: 1.7+ MB

# %%
sns.distplot(data["AveragePrice"])
# Out:
# <Axes: xlabel='AveragePrice', ylabel='Density'>

# %%
sns.countplot(x = "year" , data = data , hue = "type")
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
data.year.value_counts()
# Out:
# year
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: count, dtype: int64

# %%
sns.boxplot(y="type", x = "AveragePrice" ,data =data)
# Out:
# <Axes: xlabel='AveragePrice', ylabel='type'>

# %%
data.year = data.year.apply(str)
sns.boxenplot(x="year", y = "AveragePrice" ,data =data)
# Out:
# <Axes: xlabel='year', ylabel='AveragePrice'>

# %%
plt.figure(figsize = (9,5))
sns.countplot(x = data["Month"])
plt.title("Mothwise Distribution of sales" , fontdict = {'fontsize':25})
# Out:
# Text(0.5, 1.0, 'Mothwise Distribution of sales')

# %% [markdown]
# ### Preperation of ML Models

# %%
data.head
# Out:
# <bound method NDFrame.head of             Date  AveragePrice  Total Volume  Total Bags  Small Bags  \
# 0     2015-12-27          1.33      64236.62     8696.87     8603.62
# 1     2015-12-20          1.35      54876.98     9505.56     9408.07
# 2     2015-12-13          0.93     118220.22     8145.35     8042.21
# 3     2015-12-06          1.08      78992.15     5811.16     5677.40
# 4     2015-11-29          1.28      51039.60     6183.95     5986.26
# ...          ...           ...           ...         ...         ...
# 18244 2018-02-04          1.63      17074.83    13498.67    13066.82
# 18245 2018-01-28          1.71      13888.04     9264.84     8940.04
# 18246 2018-01-21          1.87      13766.76     9394.11     9351.80
# 18247 2018-01-14          1.93      16205.22    10969.54    10919.54
# 18248 2018-01-07          1.62      17489.58    12014.15    11988.14
#
#        Large Bags  XLarge Bags          type  year            region  \
# ...

# %%
dummies = pd.get_dummies(data[["year","region"]],drop_first =True)
df_dummies = pd.concat([data[["Total Volume","Total Bags",
                             "Small Bags", "Large Bags", "XLarge Bags"]],dummies],axis = 1)
target = data["AveragePrice"]

from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(df_dummies,target,test_size = 0.30)

cols_to_std = ["Total Volume" , "Total Bags" , "Small Bags" , "Large Bags" , "XLarge Bags"]
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train[cols_to_std])
x_train[cols_to_std] = scaler.transform(x_train[cols_to_std])
x_test[cols_to_std] = scaler.transform(x_test[cols_to_std])

# %%
data.head()
# Out:
#    AveragePrice  Total Volume  Total Bags  Small Bags  Large Bags  \
# 0          1.33      64236.62     8696.87     8603.62       93.25
# 1          1.35      54876.98     9505.56     9408.07       97.49
# 2          0.93     118220.22     8145.35     8042.21      103.14
# 3          1.08      78992.15     5811.16     5677.40      133.76
# 4          1.28      51039.60     6183.95     5986.26      197.69
#
#    XLarge Bags          type  year  region  AveragePrice100 Month
# 0          0.0  conventional  2015  Albany            133.0   DEC
# 1          0.0  conventional  2015  Albany            135.0   DEC
# 2          0.0  conventional  2015  Albany             93.0   DEC
# 3          0.0  conventional  2015  Albany            108.0   DEC
# 4          0.0  conventional  2015  Albany            128.0   NOV

# %%
# !pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.8/124.9 MB 4.8 MB/s eta 0:00:27
#     --------------------------------------- 1.8/124.9 MB 4.8 MB/s eta 0:00:26
#     --------------------------------------- 2.9/124.9 MB 4.8 MB/s eta 0:00:26
#    - -------------------------------------- 3.7/124.9 MB 4.4 MB/s eta 0:00:28
#    - -------------------------------------- 4.7/124.9 MB 4.5 MB/s eta 0:00:27
#    - -------------------------------------- 5.5/124.9 MB 4.5 MB/s eta 0:00:27
#    -- ------------------------------------- 6.8/124.9 MB 4.7 MB/s eta 0:00:26
#    -- ------------------------------------- 7.9/124.9 MB 4.7 MB/s eta 0:00:25
#    -- ------------------------------------- 8.9/124.9 MB 4.8 MB/s eta 0:00:25
#    --- ------------------------------------ 10.2/124.9 MB 4.8 MB/s eta 0:00:24
#    --- ------------------------------------ 11.3/124.9 MB 4.9 MB/s eta 0:00:24
# ...

# %%
#importing ML models from scikit-learn
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
#to save time all models can be applied once using for loop
regressors = {
    'Linear Regression' : LinearRegression(),
    'Decision Tree' : DecisionTreeRegressor(),
    'Random Forest' : RandomForestRegressor(),
    'Support Vector Machines' : SVR(gamma=1),
    'K-nearest Neighbors' : KNeighborsRegressor(n_neighbors=1),
    'XGBoost' : XGBRegressor()
}
results=pd.DataFrame(columns=['MAE','MSE','R2-score'])
for method,func in regressors.items():
    model = func.fit(x_train,y_train)
    pred = model.predict(x_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.round(r2_score(y_test,pred),3)
                         ]

# %%
results.sort_values('R2-score',ascending = False).style.background_gradient(cmap = 'Greens' , subset = ['R2-score'])
# Out:
# <style type="text/css">
# #T_b8817_row0_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_b8817_row1_col2 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_b8817_row2_col2 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_b8817_row3_col2 {
#   background-color: #18823d;
#   color: #f1f1f1;
# }
# #T_b8817_row4_col2 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_b8817_row5_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_b8817">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8817_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b8817_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b8817_level0_col2" class="col_heading level0 col2" >R2-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8817_level0_row0" class="row_heading level0 row0" >Random Forest</th>
# ...
